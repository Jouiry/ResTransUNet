# %%
import numpy as np
import cv2
img = np.fromfile('/mnt/d/Nuctech/dataset/ReconBattery2_2_800x800x400.raw',dtype='float32')

img=img.reshape((-1,800,800))

img1 = img[200]*255

cv2.imwrite("out.png", img1)
cv2.namedWindow("zhou",0)
cv2.imshow("zhou",img1)
cv2.waitKey(5)
# Out:
# (256000000,)
# (400, 800, 800)
# 50.84895
# -1

# %%
import matplotlib.pyplot as plt
img = np.fromfile('/mnt/d/Nuctech/dataset/ReconBattery2_2_800x800x400.raw',dtype='float32')
img=img.reshape((-1,800,800))
images = img[200]*255
print(images.max())
# images[images > 200] = 200
# images[images < -200] = -200

# images = images.astype(np.float32)
# images = images / 200
# images = images[32:480,32:480]
plt.imshow(images, cmap='gray')
# Out:
# 50.84895

# %%
img = cv2.imread("out.png", cv2.IMREAD_GRAYSCALE)
print(img.max())
# img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# cv2.namedWindow("demo",0)
# cv2.imshow("demo",img)
# cv2.waitKey(5)
plt.imshow(img, cmap='gray')
# Out:
# 51
